# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
from scipy import stats
from pathlib import Path
import statsmodels.api as sm
import matplotlib.pyplot as plt
from scipy.stats import pearsonr
from statsmodels.formula.api import ols
from statsmodels.stats.weightstats import ztest
from statsmodels.stats.multicomp import pairwise_tukeyhsd
from statsmodels.sandbox.stats.multicomp import multipletests

# %%
datapath = "../../r01_abcd_dti/"

# %%
abcd = pd.read_parquet(datapath + "abcd_twin_bundles.parquet")

# %%
chen = pd.read_parquet(datapath + "abcc_twin_bundle_stats_chen.parquet")
hao = pd.read_parquet(datapath + "abcc_twin_bundle_stats_hao.parquet")

# %%
print(len(chen))
print(len(hao))
# Out:
# 101336
# 101548

# %%
chen = chen[chen["number_of_tracts"].notna()]
hao = hao[hao["number_of_tracts"].notna()]
print(len(chen))
print(len(hao))
# Out:
# 61778
# 61803

# %%
metrics = ['bundle_name',
                 'number_of_tracts',
                 'mean_length_mm',
                 'span_mm',
                 'curl',
                 'elongation',
                 'total_volume_mm3',
                 'first_quarter_volume_mm3',
                 'second_and_third_quarter_volume_mm3',
                 'fourth_quarter_volume_mm3',
                 'total_surface_area_mm2',
                 'total_radius_of_end_regions_mm',
                 'total_area_of_end_regions_mm2',
                 'irregularity',
                 'area_of_end_region_1_mm2',
                 'radius_of_end_region_1_mm',
                 'volume_of_end_branches_1',
                 'area_of_end_region_2_mm2',
                 'radius_of_end_region_2_mm',
                 'volume_of_end_branches_2',
                 'qa','dti_fa',
                 'txx','txy','txz','tyy','tyz','tzz',
                 'rd1','rd2','ha','md','ad','rd',
                 'gfa','iso','rdi',
                 'nrdi02L','nrdi04L','nrdi06L',
                 'subject_id', 'Manufacturer']

# %%
chen.rename(columns = {'1st_quarter_volume_mm3' : "first_quarter_volume_mm3",
                      '2nd_and_3rd_quarter_volume_mm3' : "second_and_third_quarter_volume_mm3",
                      '4th_quarter_volume_mm3' : "fourth_quarter_volume_mm3"}, inplace = True)
hao.rename(columns = {'1st_quarter_volume_mm3' : "first_quarter_volume_mm3",
                      '2nd_and_3rd_quarter_volume_mm3' : "second_and_third_quarter_volume_mm3",
                      '4th_quarter_volume_mm3' : "fourth_quarter_volume_mm3"}, inplace = True)

# %%
def corr_clustermap(df):
    corr = df.corr(numeric_only=True)
    sns.clustermap(corr, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
            vmin=-1, vmax=1,
            cmap = "Spectral")
    plt.show()
    return corr

# %%
chen_corr = corr_clustermap(chen[metrics])

# %%
hao_corr = corr_clustermap(hao[metrics])

# %% [markdown]
# Correlation between metrics before and after update is mostly consistent

# %%
diff = chen_corr - hao_corr
sns.heatmap(diff, 
            xticklabels=corr.columns.values,
            yticklabels=corr.columns.values,
           vmin=-1, vmax=1, cmap="vlag")
plt.show()

# %%
for col in chen[metrics[1:-2]]:
    stat, p_value =  stats.ks_2samp(list(chen[col]), list(hao[col]))
    print(col + ": \n")
    print(f"statistic: {stat}")
    print(f"P-value: {p_value}" + "\n")
    fig, ax = plt.subplots()
    sns.kdeplot(data=chen, x=col, ax=ax, label="chen")
    sns.kdeplot(data=hao, x=col, ax=ax, label="hao")
    plt.legend()
    plt.show()
# Out:
# number_of_tracts:
#
# statistic: 0.026606122334508764
# P-value: 1.9693307658665775e-19
# mean_length_mm:
#
# statistic: 0.04269115262958956
# P-value: 2.298113546067874e-49
# span_mm:
#
# statistic: 0.036914125847787194
# P-value: 5.1601067149913e-37
# curl:
#
# statistic: 0.009337503983371742
# P-value: 0.009090269523533345
# elongation:
#
# statistic: 0.03796546945464396
# P-value: 3.9671932474144594e-39
# total_volume_mm3:
#
# statistic: 0.04409760248512262
# P-value: 1.2096110122767857e-52
# first_quarter_volume_mm3:
#
# statistic: 0.030271547441094948
# P-value: 4.973718643975249e-25
# second_and_third_quarter_volume_mm3:
#
# statistic: 0.037324505634087624
# P-value: 7.843080209027661e-38
# fourth_quarter_volume_mm3:
#
# statistic: 0.030271547441094948
# P-value: 4.973718643975249e-25
# total_surface_area_mm2:
#
# statistic: 0.042048696168414335
# P-value: 6.662845794204668e-48
# total_radius_of_end_regions_mm:
#
# statistic: 0.0290314773821021
# P-value: 4.690788570309791e-23
# total_area_of_end_regions_mm2:
#
# statistic: 0.03486703668156388
# P-value: 4.5571570584520936e-33
# irregularity:
#
# statistic: 0.03247431072123075
# P-value: 9.670658151588128e-29
# area_of_end_region_1_mm2:
#
# statistic: 0.03664655816530782
# P-value: 1.742730868646792e-36
# radius_of_end_region_1_mm:
#
# statistic: 0.03568007349556024
# P-value: 1.3134946452594442e-34
# volume_of_end_branches_1:
#
# statistic: 0.030271547441094948
# P-value: 4.973718643975249e-25
# area_of_end_region_2_mm2:
#
# statistic: 0.03257912059824164
# P-value: 6.344142879823166e-29
# radius_of_end_region_2_mm:
#
# statistic: 0.04840652201301257
# P-value: 2.3713869649801146e-63
# volume_of_end_branches_2:
#
# statistic: 0.030271547441094948
# P-value: 4.973718643975249e-25
# qa:
#
# statistic: 0.0030038623740468173
# P-value: 0.9423792239433768
# dti_fa:
#
# statistic: 0.008358070610420765
# P-value: 0.026544078903385948
# txx:
#
# statistic: 0.019065387311637094
# P-value: 3.471714378715008e-10
# txy:
#
# statistic: 0.010620716568312483
# P-value: 0.0018660214939744861
# txz:
#
# statistic: 0.012903334157211233
# P-value: 6.748859220900897e-05
# tyy:
#
# statistic: 0.013251698510437393
# P-value: 3.842426376621911e-05

# %%
def anova(df):
    for col in df.columns[2:-2]:
        model = ols(col + ' ~ C(Manufacturer)', data=df).fit()
        anova_table = sm.stats.anova_lm(model, typ=2)

        if anova_table["PR(>F)"][0] < 0.05:     
            print("\n" + col)
            print(anova_table)

# %%
anova(chen[metrics])
# Out:
# mean_length_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.506313e+05      1.0  125.01415  5.388199e-29
# Residual         7.443477e+07  61776.0        NaN           NaN
#
# span_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.709198e+04      1.0  56.079784  7.051150e-14
# Residual         1.882807e+07  61776.0        NaN           NaN
#
# curl
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)     11.795345      1.0  42.521833  7.043469e-11
# Residual         17136.355584  61776.0        NaN           NaN
#
# elongation
#                        sum_sq       df          F    PR(>F)
# C(Manufacturer)  1.391877e+03      1.0  21.945335  0.000003
# Residual         3.918128e+06  61776.0        NaN       NaN
#
# total_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  8.642102e+09      1.0  66.046054  4.485864e-16
# Residual         8.083367e+12  61776.0        NaN           NaN
#
# first_quarter_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.664202e+08      1.0  93.988169  3.292050e-22
# Residual         4.380208e+11  61776.0        NaN           NaN
#
# second_and_third_quarter_volume_mm3
#                        sum_sq       df         F        PR(>F)
# C(Manufacturer)  1.708389e+09      1.0  32.73655  1.060203e-08
# Residual         3.223842e+12  61776.0       NaN           NaN
#
# fourth_quarter_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.664202e+08      1.0  93.988169  3.292050e-22
# Residual         4.380208e+11  61776.0        NaN           NaN
#
# total_surface_area_mm2
#                        sum_sq       df       F    PR(>F)
# C(Manufacturer)  2.093501e+09      1.0  5.3583  0.020627
# Residual         2.413603e+13  61776.0     NaN       NaN
#
# total_radius_of_end_regions_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.598966e+03      1.0  30.505758  3.342140e-08
# Residual         3.238003e+06  61776.0        NaN           NaN
#
# total_area_of_end_regions_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  1.374003e+09      1.0  135.340432  2.998422e-31
# Residual         6.271622e+11  61776.0         NaN           NaN
#
# irregularity
#                         sum_sq       df          F        PR(>F)
# C(Manufacturer)     239.761732      1.0  75.414303  3.907302e-18
# Residual         196402.010504  61776.0        NaN           NaN
#
# area_of_end_region_1_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  3.458368e+08      1.0  120.173387  6.150976e-28
# Residual         1.777799e+11  61776.0         NaN           NaN
#
# radius_of_end_region_1_mm
#                        sum_sq       df          F    PR(>F)
# C(Manufacturer)  2.917584e+02      1.0  17.086171  0.000036
# Residual         1.054869e+06  61776.0        NaN       NaN
#
# volume_of_end_branches_1
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.664202e+08      1.0  93.988169  3.292050e-22
# Residual         4.380208e+11  61776.0        NaN           NaN
#
# area_of_end_region_2_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  3.411725e+08      1.0  132.561822  1.211671e-30
# Residual         1.589920e+11  61776.0         NaN           NaN
#
# radius_of_end_region_2_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  5.246898e+02      1.0  25.907892  3.591501e-07
# Residual         1.251095e+06  61776.0        NaN           NaN
#
# volume_of_end_branches_2
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.664202e+08      1.0  93.988169  3.292050e-22
# Residual         4.380208e+11  61776.0        NaN           NaN
#
# qa
#                      sum_sq       df            F  PR(>F)
# C(Manufacturer)   14.030039      1.0  3996.678728     0.0
# Residual         216.859978  61776.0          NaN     NaN
#
# dti_fa
#                      sum_sq       df          F        PR(>F)
# C(Manufacturer)    0.293379      1.0  50.445535  1.238359e-12
# Residual         359.274738  61776.0        NaN           NaN
#
# txx
#                    sum_sq       df          F         PR(>F)
# C(Manufacturer)  0.000020      1.0  594.95858  8.721577e-131
# Residual         0.002116  61776.0        NaN            NaN
#
# txy
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.194299e-07      1.0  34.861675  3.558244e-09
# Residual         2.116337e-04  61776.0        NaN           NaN
#
# tyy
#                    sum_sq       df           F         PR(>F)
# C(Manufacturer)  0.000032      1.0  671.696744  2.631596e-147
# Residual         0.002969  61776.0         NaN            NaN
#
# tzz
#                    sum_sq       df            F  PR(>F)
# C(Manufacturer)  0.000062      1.0  2013.529429     0.0
# Residual         0.001888  61776.0          NaN     NaN
#
# rd1
#                       sum_sq       df            F  PR(>F)
# C(Manufacturer)    68.216390      1.0  2386.212207     0.0
# Residual         1766.035602  61776.0          NaN     NaN
#
# rd2
#                       sum_sq       df           F         PR(>F)
# C(Manufacturer)    15.046615      1.0  541.778219  2.531411e-119
# Residual         1715.682980  61776.0         NaN            NaN
#
# md
#                       sum_sq       df            F         PR(>F)
# C(Manufacturer)    36.167290      1.0  1328.566152  8.100317e-288
# Residual         1681.715683  61776.0          NaN            NaN
#
# ad
#                       sum_sq       df           F         PR(>F)
# C(Manufacturer)    34.850792      1.0  968.034743  6.851964e-211
# Residual         2224.034336  61776.0         NaN            NaN
#
# rd
#                       sum_sq       df            F         PR(>F)
# C(Manufacturer)    36.834716      1.0  1320.756483  3.715359e-286
# Residual         1722.877318  61776.0          NaN            NaN
#
# gfa
#                     sum_sq       df            F  PR(>F)
# C(Manufacturer)   1.326536      1.0  4657.640227     0.0
# Residual         17.564149  61670.0          NaN     NaN
#
# iso
#                      sum_sq       df           F        PR(>F)
# C(Manufacturer)    3.874658      1.0  331.707545  6.378785e-74
# Residual         721.602206  61776.0         NaN           NaN
#
# rdi
#                      sum_sq       df           F         PR(>F)
# C(Manufacturer)    2.987293      1.0  508.628794  3.585334e-112
# Residual         362.824572  61776.0         NaN            NaN
#
# nrdi02L
#                      sum_sq       df           F         PR(>F)
# C(Manufacturer)    2.666061      1.0  686.072859  2.127569e-150
# Residual         240.059947  61776.0         NaN            NaN
#
# nrdi04L
#                     sum_sq       df           F         PR(>F)
# C(Manufacturer)   0.203381      1.0  852.405428  4.045637e-186
# Residual         14.739558  61776.0         NaN            NaN
#
# nrdi06L
#                    sum_sq       df           F         PR(>F)
# C(Manufacturer)  0.000587      1.0  668.837223  1.084938e-146
# Residual         0.054250  61776.0         NaN            NaN

# %%
anova(hao[metrics])
# Out:
# mean_length_mm
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  1.304041e+05      1.0  116.634998  3.649118e-27
# Residual         6.909681e+07  61801.0         NaN           NaN
#
# span_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.405095e+04      1.0  49.553494  1.950392e-12
# Residual         1.752375e+07  61801.0        NaN           NaN
#
# curl
#                       sum_sq       df          F        PR(>F)
# C(Manufacturer)     15.43951      1.0  60.707894  6.723062e-15
# Residual         15717.51348  61801.0        NaN           NaN
#
# elongation
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  2.518058e+03      1.0  38.924578  4.433445e-10
# Residual         3.997950e+06  61801.0        NaN           NaN
#
# total_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.009955e+10      1.0  78.279411  9.175011e-19
# Residual         7.973519e+12  61801.0        NaN           NaN
#
# first_quarter_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.430408e+08      1.0  90.407607  2.004744e-21
# Residual         4.395710e+11  61801.0        NaN           NaN
#
# second_and_third_quarter_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  2.478052e+09      1.0  49.377978  2.132779e-12
# Residual         3.101507e+12  61801.0        NaN           NaN
#
# fourth_quarter_volume_mm3
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.430408e+08      1.0  90.407607  2.004744e-21
# Residual         4.395710e+11  61801.0        NaN           NaN
#
# total_surface_area_mm2
#                        sum_sq       df         F    PR(>F)
# C(Manufacturer)  3.645794e+09      1.0  9.617342  0.001928
# Residual         2.342786e+13  61801.0       NaN       NaN
#
# total_radius_of_end_regions_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  1.680107e+03      1.0  34.391955  4.528667e-09
# Residual         3.019087e+06  61801.0        NaN           NaN
#
# total_area_of_end_regions_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  1.602746e+09      1.0  155.975141  9.469220e-36
# Residual         6.350455e+11  61801.0         NaN           NaN
#
# irregularity
#                         sum_sq       df          F        PR(>F)
# C(Manufacturer)     202.070192      1.0  65.904789  4.818778e-16
# Residual         189487.593976  61801.0        NaN           NaN
#
# area_of_end_region_1_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  3.964124e+08      1.0  137.646723  9.409558e-32
# Residual         1.779823e+11  61801.0         NaN           NaN
#
# radius_of_end_region_1_mm
#                        sum_sq       df          F    PR(>F)
# C(Manufacturer)  2.524725e+02      1.0  15.378711  0.000088
# Residual         1.014588e+06  61801.0        NaN       NaN
#
# volume_of_end_branches_1
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.430408e+08      1.0  90.407607  2.004744e-21
# Residual         4.395710e+11  61801.0        NaN           NaN
#
# area_of_end_region_2_mm2
#                        sum_sq       df           F        PR(>F)
# C(Manufacturer)  4.049841e+08      1.0  155.077042  1.486208e-35
# Residual         1.613935e+11  61801.0         NaN           NaN
#
# radius_of_end_region_2_mm
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.299963e+02      1.0  35.207308  2.979825e-09
# Residual         1.105861e+06  61801.0        NaN           NaN
#
# volume_of_end_branches_2
#                        sum_sq       df          F        PR(>F)
# C(Manufacturer)  6.430408e+08      1.0  90.407607  2.004744e-21
# Residual         4.395710e+11  61801.0        NaN           NaN
#
# qa
#                      sum_sq       df            F  PR(>F)
# C(Manufacturer)   13.952098      1.0  3993.148097     0.0
# Residual         215.933285  61801.0          NaN     NaN
#
# dti_fa
#                      sum_sq       df          F        PR(>F)
# C(Manufacturer)    0.319978      1.0  54.099965  1.928964e-13
# Residual         365.526376  61801.0        NaN           NaN
#
# txx
#                    sum_sq       df           F         PR(>F)
# C(Manufacturer)  0.000019      1.0  637.377199  6.388955e-140
# Residual         0.001877  61801.0         NaN            NaN
#
# txy
#                        sum_sq       df         F    PR(>F)
# C(Manufacturer)  7.569808e-08      1.0  23.42542  0.000001
# Residual         1.997069e-04  61801.0       NaN       NaN
#
# tyy
#                    sum_sq       df           F         PR(>F)
# C(Manufacturer)  0.000032      1.0  706.052441  1.074524e-154
# Residual         0.002831  61801.0         NaN            NaN
#
# tzz
#                    sum_sq       df           F  PR(>F)
# C(Manufacturer)  0.000061      1.0  2000.96532     0.0
# Residual         0.001881  61801.0         NaN     NaN
#
# rd1
#                       sum_sq       df            F  PR(>F)
# C(Manufacturer)    67.284990      1.0  2499.468625     0.0
# Residual         1663.665487  61801.0          NaN     NaN
#
# rd2
#                       sum_sq       df           F         PR(>F)
# C(Manufacturer)    15.273463      1.0  571.295455  1.094960e-125
# Residual         1652.236651  61801.0         NaN            NaN
#
# md
#                       sum_sq       df            F         PR(>F)
# C(Manufacturer)    35.566532      1.0  1399.304646  7.367016e-303
# Residual         1570.813922  61801.0          NaN            NaN
#
# ad
#                       sum_sq       df            F         PR(>F)
# C(Manufacturer)    33.413477      1.0  1007.422344  2.560301e-219
# Residual         2049.772187  61801.0          NaN            NaN
#
# rd
#                       sum_sq       df          F         PR(>F)
# C(Manufacturer)    36.668304      1.0  1381.5401  4.391823e-299
# Residual         1640.298272  61801.0        NaN            NaN
#
# gfa
#                     sum_sq       df            F  PR(>F)
# C(Manufacturer)   1.319897      1.0  4544.881155     0.0
# Residual         17.942362  61782.0          NaN     NaN
#
# iso
#                      sum_sq       df           F        PR(>F)
# C(Manufacturer)    3.541027      1.0  307.822468  9.562791e-69
# Residual         710.926018  61801.0         NaN           NaN
#
# rdi
#                      sum_sq       df           F         PR(>F)
# C(Manufacturer)    2.863707      1.0  495.053146  3.050145e-109
# Residual         357.496821  61801.0         NaN            NaN
#
# nrdi02L
#                      sum_sq       df           F         PR(>F)
# C(Manufacturer)    2.464838      1.0  651.027825  7.366710e-143
# Residual         233.982981  61801.0         NaN            NaN
#
# nrdi04L
#                     sum_sq       df           F         PR(>F)
# C(Manufacturer)   0.178156      1.0  767.880337  5.568094e-168
# Residual         14.338436  61801.0         NaN            NaN
#
# nrdi06L
#                    sum_sq       df           F         PR(>F)
# C(Manufacturer)  0.000731      1.0  577.161349  5.958978e-127
# Residual         0.078239  61801.0         NaN            NaN
